# %%
import sqlite3
import pandas as pd
from tqdm import tqdm

tqdm.pandas()

# %%
def set_df_labels(df):
    df['Label'] = df['Subject'] + " " + \
        df['Number'].astype(str)
    return df

# %%
df_sp23 = set_df_labels(pd.read_csv("./csv/2023-sp.csv"))
df_fa22 = set_df_labels(pd.read_csv("./csv/2022-fa.csv"))
df_sp22 = set_df_labels(pd.read_csv("./csv/2022-sp.csv"))
df_sp21 = set_df_labels(pd.read_csv("./csv/2021-sp.csv"))
df_fa21 = set_df_labels(pd.read_csv("./csv/2021-fa.csv"))
df_sp20 = set_df_labels(pd.read_csv("./csv/2020-sp.csv"))
df_fa20 = set_df_labels(pd.read_csv("./csv/2020-fa.csv"))
df_sp19 = set_df_labels(pd.read_csv("./csv/2019-sp.csv"))
df_fa19 = set_df_labels(pd.read_csv("./csv/2019-fa.csv"))
df_sp18 = set_df_labels(pd.read_csv("./csv/2018-sp.csv"))
df_fa18 = set_df_labels(pd.read_csv("./csv/2018-fa.csv"))

# %%
df_data = pd.concat([df_sp23,
df_fa22,
df_sp22,
df_sp21,
df_fa21,
df_sp20,
df_fa20,
])
df_data
# Out:
#        Year    Term YearTerm Subject  Number                          Name  \
# 0      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 4      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 12125  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12126  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12127  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12128  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12129  2018    Fall  2018-fa    YDSH     103        Intermediate Yiddish I
#
#                                              Description Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 12125                    Same as INFO 303. See INFO 303.     3 hours.
# 12126                    Same as INFO 303. See INFO 303.     3 hours.
# 12127                    Same as INFO 303. See INFO 303.     3 hours.
# 12128                    Same as INFO 303. See INFO 303.     3 hours.
# 12129  Continuation of YDSH 102. Develops more advanc...     4 hours.
#
#                                             Section Info  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12125                    Same as INFO 303. See INFO 303.
# 12126                    Same as INFO 303. See INFO 303.
# 12127                    Same as INFO 303. See INFO 303.
# 12128                    Same as INFO 303. See INFO 303.
# 12129  Prerequisite: YDSH 102 or equivalent placement...
#
#                                        Degree Attributes  ...  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# ...                                                  ...  ...
# 12125                       Advanced Composition course.  ...
# 12126                       Advanced Composition course.  ...
# 12127                       Advanced Composition course.  ...
# 12128                       Advanced Composition course.  ...
# 12129                                                NaN  ...
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 0                  Open  Discussion/Recitation       DIS   09:00 AM  09:50 AM
# 1                  Open  Discussion/Recitation       DIS   10:00 AM  10:50 AM
# 2                  Open  Discussion/Recitation       DIS   11:00 AM  11:50 AM
# 3                  Open  Discussion/Recitation       DIS   12:00 PM  12:50 PM
# 4                  Open  Discussion/Recitation       DIS   01:00 PM  01:50 PM
# ...                 ...                    ...       ...        ...       ...
# 12125           UNKNOWN                Lecture       LEC   09:30 AM  10:45 AM
# 12126           UNKNOWN                Lecture       LEC   11:00 AM  12:15 PM
# 12127           UNKNOWN                Lecture       LEC   12:30 PM  01:45 PM
# 12128           UNKNOWN                Lecture       LEC   02:00 PM  03:15 PM
# 12129           UNKNOWN     Lecture-Discussion       LCD   ARRANGED       NaN
#
#       Days of Week Room           Building               Instructors     Label
# 0                F  242        Bevier Hall          Park, D;Zheng, R   AAS 100
# 1                F  317  David Kinley Hall          Park, D;Zheng, R   AAS 100
# 2                F  317  David Kinley Hall  Park, D;Rosado-Torres, A   AAS 100
# 3                F  242        Bevier Hall  Park, D;Rosado-Torres, A   AAS 100
# 4                F  212     Davenport Hall                       NaN   AAS 100
# ...            ...  ...                ...                       ...       ...
# 12125           TR    9       Gregory Hall                 Lafond, B  WRIT 303
# 12126           TR    9       Gregory Hall             Kapczynski, A  WRIT 303
# 12127           TR    9       Gregory Hall             Turnipseed, N  WRIT 303
# 12128           TR    9       Gregory Hall       Carvajal Regidor, M  WRIT 303
# 12129          NaN  NaN                NaN                Feldman, S  YDSH 103
#
# [131638 rows x 28 columns]

# %%
data_all = []
labels_seen = set()

# %%
for idx, col in df_data.iterrows():
    if col['Label'] not in labels_seen:
        labels_seen.add(col['Label'])
        data_all.append(col)

# %%
df_all = pd.DataFrame(data_all)
df_all
# Out:
#        Year    Term YearTerm Subject  Number                             Name  \
# 0      2023  Spring  2023-sp     AAS     100     Intro Asian American Studies
# 11     2023  Spring  2023-sp     AAS     200             U.S. Race and Empire
# 12     2023  Spring  2023-sp     AAS     201  US Racial &amp; Ethnic Politics
# 16     2023  Spring  2023-sp     AAS     215     US Citizenship Comparatively
# 17     2023  Spring  2023-sp     AAS     282     Feminist and Queer Activisms
# ...     ...     ...      ...     ...     ...                              ...
# 11997  2018    Fall  2018-fa      UP     426        Urban Design and Planning
# 12024  2018    Fall  2018-fa     VCM     553      Advanced Diagnostic Imaging
# 12072  2018    Fall  2018-fa     VCM     639     Forensic Veterinary Medicine
# 12084  2018    Fall  2018-fa     VCM     677             Study Abroad Germany
# 12114  2018    Fall  2018-fa      VM     620           Canine Feline Behavior
#
#                                              Description   Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...       3 hours.
# 11     Invites students to examine histories and narr...       3 hours.
# 12     Same as AFRO 201, LLS 201, and PS 201. See PS ...       3 hours.
# 16     Examines the racial, gendered, and sexualized ...       3 hours.
# 17             Same as GWS 282 and LLS 282. See GWS 282.       3 hours.
# ...                                                  ...            ...
# 11997  Concepts and techniques of urban analysis, pla...       4 hours.
# 12024  Reviews the physics, clinical indications and ...       1 hours.
# 12072  This is a small group discussion and lecture-s...       1 hours.
# 12084  Study Abroad Program to learn about public hea...     1.5 hours.
# 12114  This lecture/discussion course examines the ev...  1 OR 3 hours.
#
#                                             Section Info  \
# 0                                                    NaN
# 11                                      Same as LLS 200.
# 12     Same as AFRO 201, LLS 201, and PS 201. See PS ...
# 16     Same as AFRO 215, AIS 295, GWS 215, and LLS 21...
# 17             Same as GWS 282 and LLS 282. See GWS 282.
# ...                                                  ...
# 11997  4 undergraduate hours. 4 graduate hours. Prere...
# 12024  May be repeated in separate terms for unlimite...
# 12072  No graduate credit. 1 professional hour. Appro...
# 12084                     Approved for S/U grading only.
# 12114     No graduate credit. 1 or 3 professional hours.
#
#                                        Degree Attributes  ...  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 11     Humanities - Hist & Phil, and Cultural Studies...  ...
# 12     Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 16     Humanities - Hist & Phil, and Cultural Studies...  ...
# 17                Cultural Studies - US Minority course.  ...
# ...                                                  ...  ...
# 11997                                                NaN  ...
# 12024                                                NaN  ...
# 12072                                                NaN  ...
# 12084                                                NaN  ...
# 12114                                                NaN  ...
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 0                  Open  Discussion/Recitation       DIS   09:00 AM  09:50 AM
# 11        CrossListOpen     Lecture-Discussion       LCD   02:00 PM  03:20 PM
# 12               Closed                 Online       ONL   ARRANGED       NaN
# 16        CrossListOpen     Lecture-Discussion       LCD   12:00 PM  01:20 PM
# 17        CrossListOpen     Lecture-Discussion       LCD   02:00 PM  03:20 PM
# ...                 ...                    ...       ...        ...       ...
# 11997           UNKNOWN                Lecture       LEC   03:30 PM  06:20 PM
# 12024           UNKNOWN     Lecture-Discussion       LCD   08:00 AM  10:00 AM
# 12072           UNKNOWN     Lecture-Discussion       LCD   03:00 PM  03:50 PM
# 12084           UNKNOWN     Lecture-Discussion       LCD   ARRANGED       NaN
# 12114           UNKNOWN     Lecture-Discussion       LCD   04:00 PM  05:50 PM
#
#       Days of Week Room                 Building          Instructors    Label
# 0                F  242              Bevier Hall     Park, D;Zheng, R  AAS 100
# 11              TR  322        David Kinley Hall                  NaN  AAS 200
# 12             NaN  NaN                      NaN                  NaN  AAS 201
# 16              MW  219        David Kinley Hall              Kwon, S  AAS 215
# 17              TR  221             Gregory Hall          McCarthy, D  AAS 282
# ...            ...  ...                      ...                  ...      ...
# 11997            R  223  Temple Hoyne Buell Hall  Lavigne, D;Tarum, K   UP 426
# 12024            M  NaN                      NaN          Matheson, J  VCM 553
# 12072           TR  NaN                      NaN           Foreman, J  VCM 639
# 12084          NaN  NaN                      NaN            Hoenig, M  VCM 677
# 12114            M  NaN                      NaN        Ballantyne, K   VM 620
#
# [8680 rows x 28 columns]

# %%
df_all[(df_all['Subject'] == 'ECE') & (df_all['Number'] == 385)].iloc[0]
# Out:
# Year                                                                 2023
# Term                                                               Spring
# YearTerm                                                          2023-sp
# Subject                                                               ECE
# Number                                                                385
# Name                                           Digital Systems Laboratory
# Description             Design, build, and test digital systems using ...
# Credit Hours                                                     3 hours.
# Section Info                           Prerequisite: ECE 110 and ECE 220.
# Degree Attributes                                                     NaN
# Schedule Information    Students must register for one lab and one lec...
# CRN                                                                 32782
# Section                                                               AL1
# Status Code                                                             A
# Part of Term                                                            1
# Section Title                                                         NaN
# Section Credit Hours                                                  NaN
# Section Status                                                          A
# Enrollment Status                                       Open (Restricted)
# Type                                                           Laboratory
# Type Code                                                             LAB
# Start Time                                                       ARRANGED
# End Time                                                              NaN
# Days of Week                                                          NaN
# Room                                                                  NaN
# Building                                                              NaN
# Instructors                                                      Cheng, Z
# Label                                                             ECE 385
# Name: 3857, dtype: object

# %%
df_exp = df_all.head()
df_exp
# Out:
#     Year    Term YearTerm Subject  Number                             Name  \
# 0   2023  Spring  2023-sp     AAS     100     Intro Asian American Studies
# 11  2023  Spring  2023-sp     AAS     200             U.S. Race and Empire
# 12  2023  Spring  2023-sp     AAS     201  US Racial &amp; Ethnic Politics
# 16  2023  Spring  2023-sp     AAS     215     US Citizenship Comparatively
# 17  2023  Spring  2023-sp     AAS     282     Feminist and Queer Activisms
#
#                                           Description Credit Hours  \
# 0   Interdisciplinary introduction to the basic co...     3 hours.
# 11  Invites students to examine histories and narr...     3 hours.
# 12  Same as AFRO 201, LLS 201, and PS 201. See PS ...     3 hours.
# 16  Examines the racial, gendered, and sexualized ...     3 hours.
# 17          Same as GWS 282 and LLS 282. See GWS 282.     3 hours.
#
#                                          Section Info  \
# 0                                                 NaN
# 11                                   Same as LLS 200.
# 12  Same as AFRO 201, LLS 201, and PS 201. See PS ...
# 16  Same as AFRO 215, AIS 295, GWS 215, and LLS 21...
# 17          Same as GWS 282 and LLS 282. See GWS 282.
#
#                                     Degree Attributes  ... Enrollment Status  \
# 0   Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              Open
# 11  Humanities - Hist & Phil, and Cultural Studies...  ...     CrossListOpen
# 12  Social & Beh Sci - Soc Sci, and Cultural Studi...  ...            Closed
# 16  Humanities - Hist & Phil, and Cultural Studies...  ...     CrossListOpen
# 17             Cultural Studies - US Minority course.  ...     CrossListOpen
#
#                      Type Type Code Start Time  End Time Days of Week Room  \
# 0   Discussion/Recitation       DIS   09:00 AM  09:50 AM            F  242
# 11     Lecture-Discussion       LCD   02:00 PM  03:20 PM           TR  322
# 12                 Online       ONL   ARRANGED       NaN          NaN  NaN
# 16     Lecture-Discussion       LCD   12:00 PM  01:20 PM           MW  219
# 17     Lecture-Discussion       LCD   02:00 PM  03:20 PM           TR  221
#
#              Building       Instructors    Label
# 0         Bevier Hall  Park, D;Zheng, R  AAS 100
# 11  David Kinley Hall               NaN  AAS 200
# 12                NaN               NaN  AAS 201
# 16  David Kinley Hall           Kwon, S  AAS 215
# 17       Gregory Hall       McCarthy, D  AAS 282
#
# [5 rows x 28 columns]

# %%
def preprocess_df(df) -> pd.DataFrame:
    df.columns = [x.lower().replace(' ', '_') for x in df.columns]
    return df

# %%
df_all = preprocess_df(df_data)
df_all
# Out:
#        year    term yearterm subject  number                          name  \
# 0      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 1      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 2      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 3      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# 4      2023  Spring  2023-sp     AAS     100  Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                           ...
# 12125  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12126  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12127  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12128  2018    Fall  2018-fa    WRIT     303          Writing Across Media
# 12129  2018    Fall  2018-fa    YDSH     103        Intermediate Yiddish I
#
#                                              description credit_hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 12125                    Same as INFO 303. See INFO 303.     3 hours.
# 12126                    Same as INFO 303. See INFO 303.     3 hours.
# 12127                    Same as INFO 303. See INFO 303.     3 hours.
# 12128                    Same as INFO 303. See INFO 303.     3 hours.
# 12129  Continuation of YDSH 102. Develops more advanc...     4 hours.
#
#                                             section_info  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12125                    Same as INFO 303. See INFO 303.
# 12126                    Same as INFO 303. See INFO 303.
# 12127                    Same as INFO 303. See INFO 303.
# 12128                    Same as INFO 303. See INFO 303.
# 12129  Prerequisite: YDSH 102 or equivalent placement...
#
#                                        degree_attributes  ...  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# ...                                                  ...  ...
# 12125                       Advanced Composition course.  ...
# 12126                       Advanced Composition course.  ...
# 12127                       Advanced Composition course.  ...
# 12128                       Advanced Composition course.  ...
# 12129                                                NaN  ...
#
#       enrollment_status                   type type_code start_time  end_time  \
# 0                  Open  Discussion/Recitation       DIS   09:00 AM  09:50 AM
# 1                  Open  Discussion/Recitation       DIS   10:00 AM  10:50 AM
# 2                  Open  Discussion/Recitation       DIS   11:00 AM  11:50 AM
# 3                  Open  Discussion/Recitation       DIS   12:00 PM  12:50 PM
# 4                  Open  Discussion/Recitation       DIS   01:00 PM  01:50 PM
# ...                 ...                    ...       ...        ...       ...
# 12125           UNKNOWN                Lecture       LEC   09:30 AM  10:45 AM
# 12126           UNKNOWN                Lecture       LEC   11:00 AM  12:15 PM
# 12127           UNKNOWN                Lecture       LEC   12:30 PM  01:45 PM
# 12128           UNKNOWN                Lecture       LEC   02:00 PM  03:15 PM
# 12129           UNKNOWN     Lecture-Discussion       LCD   ARRANGED       NaN
#
#       days_of_week room           building               instructors     label
# 0                F  242        Bevier Hall          Park, D;Zheng, R   AAS 100
# 1                F  317  David Kinley Hall          Park, D;Zheng, R   AAS 100
# 2                F  317  David Kinley Hall  Park, D;Rosado-Torres, A   AAS 100
# 3                F  242        Bevier Hall  Park, D;Rosado-Torres, A   AAS 100
# 4                F  212     Davenport Hall                       NaN   AAS 100
# ...            ...  ...                ...                       ...       ...
# 12125           TR    9       Gregory Hall                 Lafond, B  WRIT 303
# 12126           TR    9       Gregory Hall             Kapczynski, A  WRIT 303
# 12127           TR    9       Gregory Hall             Turnipseed, N  WRIT 303
# 12128           TR    9       Gregory Hall       Carvajal Regidor, M  WRIT 303
# 12129          NaN  NaN                NaN                Feldman, S  YDSH 103
#
# [131638 rows x 28 columns]

# %%
df_all["gpa"] = "None"
df_all["yearterm"] = df_all["term"] + " " + df_all["year"].astype(str)

# %%
df_gpa = pd.read_csv("csv/gpa/gpa-dataset.csv")
df_gpa['Label'] = df_gpa["Subject"] + " " + df_gpa["Number"].astype(str)

# %%
df_gpa_cache = {}

# %%
#https://github.com/illinois/reddit-uiuc-bot/blob/master/process_reddit_post.py
def get_recent_average_gpa(course):
    if course in df_gpa_cache:
        return df_gpa_cache[course]
    
    df = df_gpa[df_gpa["Label"] == course].groupby("Label").agg("sum").reset_index()
    if len(df) == 0: return None

    df["Count GPA"] = df["A+"] + df["A"] + df["A-"] + df["B+"] + df["B"] + df["B-"] + df["C+"] + df["C"] + df["C-"] + df["D+"] + df["D"] + df["D-"] + df["W"]
    df["Sum GPA"] = (4 * (df["A+"] + df["A"])) + (3.67 * df["A-"]) + \
    (3.33 * df["B+"]) + (3 * df["B"]) + (2.67 * df["B-"]) + \
    (2.33 * df["C+"]) + (2 * df["C"]) + (1.67 * df["C-"]) + \
    (1.33 * df["D+"]) + (1 * df["D"]) + (0.67 * df["D-"])

    avg = (df["Sum GPA"] / df["Count GPA"]).round(3)
    df["Average GPA"] = avg
    df_gpa_cache[course] = avg
    return df["Average GPA"].values[0]

# %%
def map_gpas(row):
    recent_gpa = get_recent_average_gpa(row["label"])
    recent_gpa = "Not Available" if recent_gpa is None else str(round(recent_gpa, 2))
    row["gpa"] = recent_gpa 
    return row

# %%
df_n = df_all.progress_apply(map_gpas, axis=1)
# Out:
# 100%|██████████| 131638/131638 [06:06<00:00, 358.86it/s]

# %%
df_n[df_n["label"] == "ECE 391"]
# Out:
#       year    term     yearterm subject  number                          name  \
# 3859  2023  Spring  Spring 2023     ECE     391  Computer Systems Engineering
# 3860  2023  Spring  Spring 2023     ECE     391  Computer Systems Engineering
# 3861  2023  Spring  Spring 2023     ECE     391  Computer Systems Engineering
# 3862  2023  Spring  Spring 2023     ECE     391  Computer Systems Engineering
# 3863  2023  Spring  Spring 2023     ECE     391  Computer Systems Engineering
# ...    ...     ...          ...     ...     ...                           ...
# 3885  2018    Fall    Fall 2018     ECE     391  Computer Systems Engineering
# 3886  2018    Fall    Fall 2018     ECE     391  Computer Systems Engineering
# 3887  2018    Fall    Fall 2018     ECE     391  Computer Systems Engineering
# 3888  2018    Fall    Fall 2018     ECE     391  Computer Systems Engineering
# 3889  2018    Fall    Fall 2018     ECE     391  Computer Systems Engineering
#
#                                             description credit_hours  \
# 3859  Concepts and abstractions central to the devel...     4 hours.
# 3860  Concepts and abstractions central to the devel...     4 hours.
# 3861  Concepts and abstractions central to the devel...     4 hours.
# 3862  Concepts and abstractions central to the devel...     4 hours.
# 3863  Concepts and abstractions central to the devel...     4 hours.
# ...                                                 ...          ...
# 3885  Concepts and abstractions central to the devel...     4 hours.
# 3886  Concepts and abstractions central to the devel...     4 hours.
# 3887  Concepts and abstractions central to the devel...     4 hours.
# 3888  Concepts and abstractions central to the devel...     4 hours.
# 3889  Concepts and abstractions central to the devel...     4 hours.
#
#                                            section_info degree_attributes  \
# 3859  Credit is not given for both ECE 391 and eithe...               NaN
# 3860  Credit is not given for both ECE 391 and eithe...               NaN
# 3861  Credit is not given for both ECE 391 and eithe...               NaN
# 3862  Credit is not given for both ECE 391 and eithe...               NaN
# 3863  Credit is not given for both ECE 391 and eithe...               NaN
# ...                                                 ...               ...
# 3885  Credit is not given for both ECE 391 and CS 24...               NaN
# 3886  Credit is not given for both ECE 391 and CS 24...               NaN
# 3887  Credit is not given for both ECE 391 and CS 24...               NaN
# 3888  Credit is not given for both ECE 391 and CS 24...               NaN
# 3889  Credit is not given for both ECE 391 and CS 24...               NaN
#
#       ...                   type  type_code start_time  end_time days_of_week  \
# 3859  ...  Discussion/Recitation        DIS   02:00 PM  02:50 PM            W
# 3860  ...  Discussion/Recitation        DIS   11:00 AM  11:50 AM            W
# 3861  ...  Discussion/Recitation        DIS   01:00 PM  01:50 PM            W
# 3862  ...  Discussion/Recitation        DIS   03:00 PM  03:50 PM            W
# 3863  ...  Discussion/Recitation        DIS   10:00 AM  10:50 AM            W
# ...   ...                    ...        ...        ...       ...          ...
# 3885  ...  Discussion/Recitation        DIS   04:00 PM  04:50 PM            W
# 3886  ...  Discussion/Recitation        DIS   09:00 AM  09:50 AM            W
# 3887  ...  Discussion/Recitation        DIS   ARRANGED       NaN          NaN
# 3888  ...                Lecture        LEC   02:00 PM  03:20 PM           TR
# 3889  ...                Lecture        LEC   02:00 PM  03:20 PM           TR
#
#       room                        building             instructors    label  \
# 3859  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# 3860  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# 3861  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# 3862  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# 3863  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# ...    ...                             ...                     ...      ...
# 3885  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# 3886  3026  Electrical & Computer Eng Bldg                     NaN  ECE 391
# 3887   NaN                             NaN                     NaN  ECE 391
# 3888  1002  Electrical & Computer Eng Bldg  Huang, J;Kalbarczyk, Z  ECE 391
# 3889   NaN                             NaN           Kalbarczyk, Z  ECE 391
#
#                             gpa
# 3859                       3.08
# 3860  0    3.08\ndtype: float64
# 3861  0    3.08\ndtype: float64
# 3862  0    3.08\ndtype: float64
# 3863  0    3.08\ndtype: float64
# ...                         ...
# 3885  0    3.08\ndtype: float64
# 3886  0    3.08\ndtype: float64
# 3887  0    3.08\ndtype: float64
# 3888  0    3.08\ndtype: float64
# 3889  0    3.08\ndtype: float64
#
# [104 rows x 29 columns]

# %%
df_n[(df_n['subject'] == 'CS') & (df_n['number'] == 225)]
# Out:
#       year    term     yearterm subject  number             name  \
# 3198  2023  Spring  Spring 2023      CS     225  Data Structures
# 3199  2023  Spring  Spring 2023      CS     225  Data Structures
# 3200  2023  Spring  Spring 2023      CS     225  Data Structures
# 3201  2023  Spring  Spring 2023      CS     225  Data Structures
# 3202  2023  Spring  Spring 2023      CS     225  Data Structures
# ...    ...     ...          ...     ...     ...              ...
# 3152  2018    Fall    Fall 2018      CS     225  Data Structures
# 3153  2018    Fall    Fall 2018      CS     225  Data Structures
# 3154  2018    Fall    Fall 2018      CS     225  Data Structures
# 3155  2018    Fall    Fall 2018      CS     225  Data Structures
# 3156  2018    Fall    Fall 2018      CS     225  Data Structures
#
#                                             description credit_hours  \
# 3198  Data abstractions: elementary data structures ...     4 hours.
# 3199  Data abstractions: elementary data structures ...     4 hours.
# 3200  Data abstractions: elementary data structures ...     4 hours.
# 3201  Data abstractions: elementary data structures ...     4 hours.
# 3202  Data abstractions: elementary data structures ...     4 hours.
# ...                                                 ...          ...
# 3152  Data abstractions: elementary data structures ...     4 hours.
# 3153  Data abstractions: elementary data structures ...     4 hours.
# 3154  Data abstractions: elementary data structures ...     4 hours.
# 3155  Data abstractions: elementary data structures ...     4 hours.
# 3156  Data abstractions: elementary data structures ...     4 hours.
#
#                                            section_info  \
# 3198  Credit is not given for CS 277 if credit for C...
# 3199  Credit is not given for CS 277 if credit for C...
# 3200  Credit is not given for CS 277 if credit for C...
# 3201  Credit is not given for CS 277 if credit for C...
# 3202  Credit is not given for CS 277 if credit for C...
# ...                                                 ...
# 3152  Prerequisite: CS 125 or ECE 220; CS 173 or MAT...
# 3153  Prerequisite: CS 125 or ECE 220; CS 173 or MAT...
# 3154  Prerequisite: CS 125 or ECE 220; CS 173 or MAT...
# 3155  Prerequisite: CS 125 or ECE 220; CS 173 or MAT...
# 3156  Prerequisite: CS 125 or ECE 220; CS 173 or MAT...
#
#                       degree_attributes  ...                   type  \
# 3198  Quantitative Reasoning II course.  ...                Lecture
# 3199  Quantitative Reasoning II course.  ...                Lecture
# 3200  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# 3201  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# 3202  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# ...                                 ...  ...                    ...
# 3152  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# 3153  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# 3154  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# 3155  Quantitative Reasoning II course.  ...  Laboratory-Discussion
# 3156  Quantitative Reasoning II course.  ...  Laboratory-Discussion
#
#       type_code start_time  end_time days_of_week   room  \
# 3198        LEC   11:00 AM  11:50 AM          MWF  THEAT
# 3199        LEC   11:00 AM  11:50 AM          MWF  THEAT
# 3200        LBD   01:00 PM  02:50 PM            R   4029
# 3201        LBD   01:00 PM  02:50 PM            R   4025
# 3202        LBD   03:00 PM  04:50 PM            R   4029
# ...         ...        ...       ...          ...    ...
# 3152        LBD   03:00 PM  04:50 PM            F   1214
# 3153        LBD   11:00 AM  12:50 PM            F   1214
# 3154        LBD   05:00 PM  06:50 PM            R   1214
# 3155        LBD   09:00 AM  10:50 AM            F   1214
# 3156        LBD   05:00 PM  06:50 PM            F   1214
#
#                            building                       instructors   label  \
# 3198                   Lincoln Hall               Evans, C;Solomon, B  CS 225
# 3199                   Lincoln Hall               Evans, C;Solomon, B  CS 225
# 3200  Campus Instructional Facility               Evans, C;Solomon, B  CS 225
# 3201  Campus Instructional Facility               Evans, C;Solomon, B  CS 225
# 3202  Campus Instructional Facility               Evans, C;Solomon, B  CS 225
# ...                             ...                               ...     ...
# 3152     Siebel Center for Comp Sci  Beckman, A;Fagen-Ulmschneider, W  CS 225
# 3153     Siebel Center for Comp Sci  Beckman, A;Fagen-Ulmschneider, W  CS 225
# 3154     Siebel Center for Comp Sci  Beckman, A;Fagen-Ulmschneider, W  CS 225
# 3155     Siebel Center for Comp Sci  Beckman, A;Fagen-Ulmschneider, W  CS 225
# 3156     Siebel Center for Comp Sci  Beckman, A;Fagen-Ulmschneider, W  CS 225
#
#                             gpa
# 3198                       3.47
# 3199  0    3.47\ndtype: float64
# 3200  0    3.47\ndtype: float64
# 3201  0    3.47\ndtype: float64
# 3202  0    3.47\ndtype: float64
# ...                         ...
# 3152  0    3.47\ndtype: float64
# 3153  0    3.47\ndtype: float64
# 3154  0    3.47\ndtype: float64
# 3155  0    3.47\ndtype: float64
# 3156  0    3.47\ndtype: float64
#
# [224 rows x 29 columns]

# %%
with sqlite3.connect("sp23_courses.db") as conn:
    df_n.to_sql("classes", conn, if_exists="replace")

# %%
df_n
# Out:
#        year    term     yearterm subject  number  \
# 0      2023  Spring  Spring 2023     AAS     100
# 1      2023  Spring  Spring 2023     AAS     100
# 2      2023  Spring  Spring 2023     AAS     100
# 3      2023  Spring  Spring 2023     AAS     100
# 4      2023  Spring  Spring 2023     AAS     100
# ...     ...     ...          ...     ...     ...
# 12125  2018    Fall    Fall 2018    WRIT     303
# 12126  2018    Fall    Fall 2018    WRIT     303
# 12127  2018    Fall    Fall 2018    WRIT     303
# 12128  2018    Fall    Fall 2018    WRIT     303
# 12129  2018    Fall    Fall 2018    YDSH     103
#
#                                name  \
# 0      Intro Asian American Studies
# 1      Intro Asian American Studies
# 2      Intro Asian American Studies
# 3      Intro Asian American Studies
# 4      Intro Asian American Studies
# ...                             ...
# 12125          Writing Across Media
# 12126          Writing Across Media
# 12127          Writing Across Media
# 12128          Writing Across Media
# 12129        Intermediate Yiddish I
#
#                                              description credit_hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 12125                    Same as INFO 303. See INFO 303.     3 hours.
# 12126                    Same as INFO 303. See INFO 303.     3 hours.
# 12127                    Same as INFO 303. See INFO 303.     3 hours.
# 12128                    Same as INFO 303. See INFO 303.     3 hours.
# 12129  Continuation of YDSH 102. Develops more advanc...     4 hours.
#
#                                             section_info  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12125                    Same as INFO 303. See INFO 303.
# 12126                    Same as INFO 303. See INFO 303.
# 12127                    Same as INFO 303. See INFO 303.
# 12128                    Same as INFO 303. See INFO 303.
# 12129  Prerequisite: YDSH 102 or equivalent placement...
#
#                                        degree_attributes  ...  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...
# ...                                                  ...  ...
# 12125                       Advanced Composition course.  ...
# 12126                       Advanced Composition course.  ...
# 12127                       Advanced Composition course.  ...
# 12128                       Advanced Composition course.  ...
# 12129                                                NaN  ...
#
#                         type  type_code start_time  end_time days_of_week  \
# 0      Discussion/Recitation        DIS   09:00 AM  09:50 AM            F
# 1      Discussion/Recitation        DIS   10:00 AM  10:50 AM            F
# 2      Discussion/Recitation        DIS   11:00 AM  11:50 AM            F
# 3      Discussion/Recitation        DIS   12:00 PM  12:50 PM            F
# 4      Discussion/Recitation        DIS   01:00 PM  01:50 PM            F
# ...                      ...        ...        ...       ...          ...
# 12125                Lecture        LEC   09:30 AM  10:45 AM           TR
# 12126                Lecture        LEC   11:00 AM  12:15 PM           TR
# 12127                Lecture        LEC   12:30 PM  01:45 PM           TR
# 12128                Lecture        LEC   02:00 PM  03:15 PM           TR
# 12129     Lecture-Discussion        LCD   ARRANGED       NaN          NaN
#
#       room           building               instructors     label  \
# 0      242        Bevier Hall          Park, D;Zheng, R   AAS 100
# 1      317  David Kinley Hall          Park, D;Zheng, R   AAS 100
# 2      317  David Kinley Hall  Park, D;Rosado-Torres, A   AAS 100
# 3      242        Bevier Hall  Park, D;Rosado-Torres, A   AAS 100
# 4      212     Davenport Hall                       NaN   AAS 100
# ...    ...                ...                       ...       ...
# 12125    9       Gregory Hall                 Lafond, B  WRIT 303
# 12126    9       Gregory Hall             Kapczynski, A  WRIT 303
# 12127    9       Gregory Hall             Turnipseed, N  WRIT 303
# 12128    9       Gregory Hall       Carvajal Regidor, M  WRIT 303
# 12129  NaN                NaN                Feldman, S  YDSH 103
#
#                              gpa
# 0                           3.53
# 1      0    3.53\ndtype: float64
# 2      0    3.53\ndtype: float64
# 3      0    3.53\ndtype: float64
# 4      0    3.53\ndtype: float64
# ...                          ...
# 12125              Not Available
# 12126              Not Available
# 12127              Not Available
# 12128              Not Available
# 12129              Not Available
#
# [131638 rows x 29 columns]

# %%
load_query = 'SELECT subject,number,name,credit_hours,label,description,gpa,yearterm,degree_attributes FROM classes'
with sqlite3.connect("sp23_courses.db") as conn:
    # Use sql query to load docs into pandas dataframe.
    docs = pd.read_sql(load_query, conn).drop_duplicates(subset=['label'])
docs
# Out:
#        subject  number                             name   credit_hours  \
# 0          AAS     100     Intro Asian American Studies       3 hours.
# 11         AAS     200             U.S. Race and Empire       3 hours.
# 12         AAS     201  US Racial &amp; Ethnic Politics       3 hours.
# 16         AAS     215     US Citizenship Comparatively       3 hours.
# 17         AAS     282     Feminist and Queer Activisms       3 hours.
# ...        ...     ...                              ...            ...
# 131505      UP     426        Urban Design and Planning       4 hours.
# 131532     VCM     553      Advanced Diagnostic Imaging       1 hours.
# 131580     VCM     639     Forensic Veterinary Medicine       1 hours.
# 131592     VCM     677             Study Abroad Germany     1.5 hours.
# 131622      VM     620           Canine Feline Behavior  1 OR 3 hours.
#
#           label                                        description  \
# 0       AAS 100  Interdisciplinary introduction to the basic co...
# 11      AAS 200  Invites students to examine histories and narr...
# 12      AAS 201  Same as AFRO 201, LLS 201, and PS 201. See PS ...
# 16      AAS 215  Examines the racial, gendered, and sexualized ...
# 17      AAS 282          Same as GWS 282 and LLS 282. See GWS 282.
# ...         ...                                                ...
# 131505   UP 426  Concepts and techniques of urban analysis, pla...
# 131532  VCM 553  Reviews the physics, clinical indications and ...
# 131580  VCM 639  This is a small group discussion and lecture-s...
# 131592  VCM 677  Study Abroad Program to learn about public hea...
# 131622   VM 620  This lecture/discussion course examines the ev...
#
#                   gpa     yearterm  \
# 0                3.53  Spring 2023
# 11               3.67  Spring 2023
# 12      Not Available  Spring 2023
# 16               3.43  Spring 2023
# 17      Not Available  Spring 2023
# ...               ...          ...
# 131505           2.85    Fall 2018
# 131532  Not Available    Fall 2018
# 131580  Not Available    Fall 2018
# 131592  Not Available    Fall 2018
# 131622            3.8    Fall 2018
#
#                                         degree_attributes
# 0       Social & Beh Sci - Soc Sci, and Cultural Studi...
# 11      Humanities - Hist & Phil, and Cultural Studies...
# 12      Social & Beh Sci - Soc Sci, and Cultural Studi...
# 16      Humanities - Hist & Phil, and Cultural Studies...
# 17                 Cultural Studies - US Minority course.
# ...                                                   ...
# 131505                                               None
# 131532                                               None
# 131580                                               None
# 131592                                               None
# 131622                                               None
#
# [8680 rows x 9 columns]
